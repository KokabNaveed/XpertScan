# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define paths
data_dir = '/content/drive/MyDrive/Xpert_Scan'
train_path = f'{data_dir}/train'
test_path = f'{data_dir}/test'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load & Pre-process Data

# %%
# Define parameters
img_size = (224, 224)  # VGG16 input size
batch_size = 32

# Load training and validation data
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

# Load test data
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    image_size=img_size,
    batch_size=batch_size
)

# Apply VGG16 preprocessing
preprocess_input = tf.keras.applications.vgg16.preprocess_input
train_data = train_data.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=tf.data.AUTOTUNE)
val_data = val_data.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=tf.data.AUTOTUNE)
test_data = test_data.map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# Found 4365 files belonging to 6 classes.
# Using 3492 files for training.
# Found 4365 files belonging to 6 classes.
# Using 873 files for validation.
# Found 1876 files belonging to 6 classes.

# %% [markdown]
# ## Visualize Data

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# Define image size and batch size for VGG16
img_size = (224, 224)  # VGG16 requires 224x224 input
batch_size = 32

# Load original training data before preprocessing
original_train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,  # Set correct size for VGG16
    batch_size=batch_size
)

# Get class names from the dataset
class_names = original_train_data.class_names
print("Class Names:", class_names)

# Function to display sample images with labels
def display_sample_images(dataset, class_names):
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):  # Take one batch
        num_images = min(9, images.shape[0])  # Ensure we don't exceed batch size
        for i in range(num_images):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))  # Convert tensor to image
            plt.title(class_names[int(labels[i].numpy())])  # Convert label tensor to integer
            plt.axis("off")

# Display images from the dataset
display_sample_images(original_train_data, class_names)
# Out:
# Found 4365 files belonging to 6 classes.
# Using 3492 files for training.
# Class Names: ['COPD', 'Covid19', 'Lung_Metastasis', 'Normal', 'Pneumonia', 'Tuberculosis']

# %% [markdown]
# ## Handle Class Imbalance

# %%
# Compute class weights
labels = np.concatenate([y.numpy() for _, y in train_data], axis=0).astype(int)
unique_classes = np.unique(labels)
class_weights = compute_class_weight(class_weight="balanced", classes=unique_classes, y=labels)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# %% [markdown]
# ## Build The Modal

# %%
# Load pre-trained VGG16 model
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze the base model

# Build the classifier on top
model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(len(class_names), activation="softmax")  # Output layer with class count
])

# Compile the model
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## Define Callbacks

# %%
# Callback to save the model after each epoch
checkpoint_callback = ModelCheckpoint(
    filepath="vgg16_model_epoch_{epoch:02d}.keras",
    save_best_only=False,  # Save after every epoch
    save_weights_only=False,  # Save the entire model
    verbose=1
)

# Custom callback to display training progress
class TrainingProgressCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch + 1} complete.")
        print(f"Training Loss: {logs['loss']:.4f}, Training Accuracy: {logs['accuracy']:.4f}")
        print(f"Validation Loss: {logs['val_loss']:.4f}, Validation Accuracy: {logs['val_accuracy']:.4f}")

# %% [markdown]
# ## Train The Modal

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20,
    class_weight=class_weight_dict,
    callbacks=[checkpoint_callback, TrainingProgressCallback()],
    verbose=1
)

print("Training completed. Models saved after each epoch.")
# Out:
# Epoch 1/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.5118 - loss: 27.2195
# Epoch 1: saving model to vgg16_model_epoch_01.keras
# Epoch 1 complete.
# Training Loss: 13.3619, Training Accuracy: 0.5536
# Validation Loss: 1.3522, Validation Accuracy: 0.5452
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1923s 17s/step - accuracy: 0.5122 - loss: 27.0947 - val_accuracy: 0.5452 - val_loss: 1.3522
# Epoch 2/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.6556 - loss: 1.0912
# Epoch 2: saving model to vgg16_model_epoch_02.keras
# Epoch 2 complete.
# Training Loss: 1.0959, Training Accuracy: 0.6426
# Validation Loss: 0.9440, Validation Accuracy: 0.6094
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1929s 17s/step - accuracy: 0.6555 - loss: 1.0912 - val_accuracy: 0.6094 - val_loss: 0.9440
# Epoch 3/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.6916 - loss: 0.8630
# Epoch 3: saving model to vgg16_model_epoch_03.keras
# Epoch 3 complete.
# Training Loss: 0.9101, Training Accuracy: 0.6684
# Validation Loss: 0.8173, Validation Accuracy: 0.6552
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1967s 18s/step - accuracy: 0.6914 - loss: 0.8634 - val_accuracy: 0.6552 - val_loss: 0.8173
# Epoch 4/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.6837 - loss: 0.8215
# Epoch 4: saving model to vgg16_model_epoch_04.keras
# Epoch 4 complete.
# Training Loss: 0.8633, Training Accuracy: 0.6718
# Validation Loss: 0.8032, Validation Accuracy: 0.6919
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1920s 17s/step - accuracy: 0.6836 - loss: 0.8219 - val_accuracy: 0.6919 - val_loss: 0.8032
# Epoch 5/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7123 - loss: 0.7533
# Epoch 5: saving model to vgg16_model_epoch_05.keras
# Epoch 5 complete.
# Training Loss: 0.8026, Training Accuracy: 0.6962
# Validation Loss: 0.8154, Validation Accuracy: 0.6701
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1912s 17s/step - accuracy: 0.7121 - loss: 0.7537 - val_accuracy: 0.6701 - val_loss: 0.8154
# Epoch 6/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7073 - loss: 0.8228
# Epoch 6: saving model to vgg16_model_epoch_06.keras
# Epoch 6 complete.
# Training Loss: 0.8290, Training Accuracy: 0.7016
# Validation Loss: 0.9473, Validation Accuracy: 0.6632
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1914s 17s/step - accuracy: 0.7072 - loss: 0.8228 - val_accuracy: 0.6632 - val_loss: 0.9473
# Epoch 7/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7275 - loss: 0.7847
# Epoch 7: saving model to vgg16_model_epoch_07.keras
# Epoch 7 complete.
# Training Loss: 0.7784, Training Accuracy: 0.7179
# Validation Loss: 0.8012, Validation Accuracy: 0.7102
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1905s 17s/step - accuracy: 0.7274 - loss: 0.7846 - val_accuracy: 0.7102 - val_loss: 0.8012
# Epoch 8/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7347 - loss: 0.7868
# Epoch 8: saving model to vgg16_model_epoch_08.keras
# Epoch 8 complete.
# Training Loss: 0.8085, Training Accuracy: 0.7228
# Validation Loss: 0.7872, Validation Accuracy: 0.6976
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1905s 17s/step - accuracy: 0.7346 - loss: 0.7870 - val_accuracy: 0.6976 - val_loss: 0.7872
# Epoch 9/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7398 - loss: 0.7326
# Epoch 9: saving model to vgg16_model_epoch_09.keras
# Epoch 9 complete.
# Training Loss: 0.7875, Training Accuracy: 0.7219
# Validation Loss: 0.8447, Validation Accuracy: 0.6827
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1911s 17s/step - accuracy: 0.7397 - loss: 0.7331 - val_accuracy: 0.6827 - val_loss: 0.8447
# Epoch 10/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7631 - loss: 0.6301
# Epoch 10: saving model to vgg16_model_epoch_10.keras
# Epoch 10 complete.
# Training Loss: 0.6943, Training Accuracy: 0.7468
# Validation Loss: 0.8033, Validation Accuracy: 0.6667
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1896s 17s/step - accuracy: 0.7630 - loss: 0.6307 - val_accuracy: 0.6667 - val_loss: 0.8033
# Epoch 11/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7260 - loss: 0.6396
# Epoch 11: saving model to vgg16_model_epoch_11.keras
# Epoch 11 complete.
# Training Loss: 0.6768, Training Accuracy: 0.7191
# Validation Loss: 0.7157, Validation Accuracy: 0.7194
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1897s 17s/step - accuracy: 0.7259 - loss: 0.6399 - val_accuracy: 0.7194 - val_loss: 0.7157
# Epoch 12/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7045 - loss: 0.7047
# Epoch 12: saving model to vgg16_model_epoch_12.keras
# Epoch 12 complete.
# Training Loss: 0.6939, Training Accuracy: 0.7113
# Validation Loss: 0.7018, Validation Accuracy: 0.7194
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1934s 17s/step - accuracy: 0.7046 - loss: 0.7046 - val_accuracy: 0.7194 - val_loss: 0.7018
# Epoch 13/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7519 - loss: 0.5613
# Epoch 13: saving model to vgg16_model_epoch_13.keras
# Epoch 13 complete.
# Training Loss: 0.6105, Training Accuracy: 0.7426
# Validation Loss: 0.7494, Validation Accuracy: 0.7182
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1903s 17s/step - accuracy: 0.7518 - loss: 0.5617 - val_accuracy: 0.7182 - val_loss: 0.7494
# Epoch 14/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7555 - loss: 0.5700
# Epoch 14: saving model to vgg16_model_epoch_14.keras
# Epoch 14 complete.
# Training Loss: 0.5913, Training Accuracy: 0.7566
# Validation Loss: 0.7556, Validation Accuracy: 0.7033
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1905s 17s/step - accuracy: 0.7555 - loss: 0.5701 - val_accuracy: 0.7033 - val_loss: 0.7556
# Epoch 15/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7700 - loss: 0.5060
# Epoch 15: saving model to vgg16_model_epoch_15.keras
# Epoch 15 complete.
# Training Loss: 0.5335, Training Accuracy: 0.7721
# Validation Loss: 0.8780, Validation Accuracy: 0.7262
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2024s 18s/step - accuracy: 0.7700 - loss: 0.5062 - val_accuracy: 0.7262 - val_loss: 0.8780
# Epoch 16/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7694 - loss: 0.5189
# Epoch 16: saving model to vgg16_model_epoch_16.keras
# Epoch 16 complete.
# Training Loss: 0.5526, Training Accuracy: 0.7655
# Validation Loss: 0.8086, Validation Accuracy: 0.7331
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1984s 18s/step - accuracy: 0.7694 - loss: 0.5192 - val_accuracy: 0.7331 - val_loss: 0.8086
# Epoch 17/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7828 - loss: 0.5681
# Epoch 17: saving model to vgg16_model_epoch_17.keras
# Epoch 17 complete.
# Training Loss: 0.6099, Training Accuracy: 0.7721
# Validation Loss: 0.8593, Validation Accuracy: 0.7079
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1914s 17s/step - accuracy: 0.7827 - loss: 0.5685 - val_accuracy: 0.7079 - val_loss: 0.8593
# Epoch 18/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7687 - loss: 0.5351
# Epoch 18: saving model to vgg16_model_epoch_18.keras
# Epoch 18 complete.
# Training Loss: 0.5757, Training Accuracy: 0.7543
# Validation Loss: 0.7665, Validation Accuracy: 0.7136
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1916s 17s/step - accuracy: 0.7686 - loss: 0.5355 - val_accuracy: 0.7136 - val_loss: 0.7665
# Epoch 19/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7828 - loss: 0.4848
# Epoch 19: saving model to vgg16_model_epoch_19.keras
# Epoch 19 complete.
# Training Loss: 0.5123, Training Accuracy: 0.7792
# Validation Loss: 0.7749, Validation Accuracy: 0.7434
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1933s 18s/step - accuracy: 0.7827 - loss: 0.4851 - val_accuracy: 0.7434 - val_loss: 0.7749
# Epoch 20/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.7729 - loss: 0.5864
# Epoch 20: saving model to vgg16_model_epoch_20.keras
# Epoch 20 complete.
# Training Loss: 0.6465, Training Accuracy: 0.7552
# Validation Loss: 0.8746, Validation Accuracy: 0.7159
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1921s 17s/step - accuracy: 0.7727 - loss: 0.5870 - val_accuracy: 0.7159 - val_loss: 0.8746
# Training completed. Models saved after each epoch.

# %% [markdown]
# ## Save The Modal

# %%
# Save the trained model
model.save('/content/drive/MyDrive/Xpert_Scan/VGG.keras')

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
